# %% [markdown]
# # Fraud Detection Research Demo
#
# This notebook demonstrates the fraud detection system for research and educational purposes only.
#
# **IMPORTANT DISCLAIMER:** This is for research and educational purposes only. Not for investment advice or production use.
#
# ## Overview
#
# This notebook shows how to:
# 1. Generate synthetic transaction data
# 2. Engineer features for fraud detection
# 3. Train multiple fraud detection models
# 4. Evaluate model performance
# 5. Analyze results and feature importance
